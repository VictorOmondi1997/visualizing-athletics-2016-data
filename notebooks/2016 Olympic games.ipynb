# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The distribution of weights of medalists in gymnastics and in rowing in the 2016 Olympic games for a comparison between them

# %%
mens_rowing = pd.read_csv('../data/mens-rowing.csv')
mens_gymnastics = pd.read_csv('../data/mens_gymnastics.csv')

# %%
mens_rowing.head()
# Out:
#    Unnamed: 0    ID                          Name Sex   Age  Height  Weight  \
# 0         158    62             Giovanni Abagnale   M  21.0   198.0    90.0
# 1       11648  6346                    Jrmie Azou   M  27.0   178.0    71.0
# 2       14871  8025  Thomas Gabriel Jrmie Baroukh   M  28.0   183.0    70.0
# 3       15215  8214            Jacob Jepsen Barse   M  27.0   188.0    73.0
# 4       18441  9764          Alexander Belonogoff   M  26.0   187.0    90.0
#
#         Team  NOC        Games  Year  Season            City   Sport  \
# 0      Italy  ITA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 1     France  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 2     France  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 3    Denmark  DEN  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 4  Australia  AUS  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
#
#                                     Event   Medal
# 0              Rowing Men's Coxless Pairs  Bronze
# 1  Rowing Men's Lightweight Double Sculls    Gold
# 2  Rowing Men's Lightweight Coxless Fours  Bronze
# 3  Rowing Men's Lightweight Coxless Fours  Silver
# 4           Rowing Men's Quadruple Sculls  Silver

# %%
mens_gymnastics.head()
# Out:
#    Unnamed: 0    ID                         Name Sex   Age  Height  Weight  \
# 0         794   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 1         796   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 2         797   455  Denis Mikhaylovich Ablyazin   M  24.0   161.0    62.0
# 3       18577  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
# 4       18579  9829   David Sagitovich Belyavsky   M  24.0   165.0    55.0
#
#      Team  NOC        Games  Year  Season            City       Sport  \
# 0  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 1  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 2  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 3  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 4  Russia  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                               Event   Medal
# 0  Gymnastics Men's Team All-Around  Silver
# 1      Gymnastics Men's Horse Vault  Silver
# 2            Gymnastics Men's Rings  Bronze
# 3  Gymnastics Men's Team All-Around  Silver
# 4    Gymnastics Men's Parallel Bars  Bronze

# %% [markdown]
# # Comparing the distribution of "Weight" in mens_rowing and mens_gymnastics

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing.Weight, histtype='step', bins=5, label='Rowing')
ax.hist(mens_gymnastics.Weight, histtype='step', bins=5, label='Gymnastics')
ax.set_xlabel('Weight (kg)')
ax.set_ylabel('# of observations')
ax.legend()
plt.show()

# %% [markdown]
# Selecting groups from the Summer 2016 Olympic Games medalist dataset to compare the height of medalist athletes in two different sports.
#
# # Adding error bars

# %%
fig, ax = plt.subplots()
ax.bar('Rowing', mens_rowing.Height.mean(), yerr=mens_rowing.Height.std())
ax.bar('Gymnastics', mens_gymnastics.Height.mean(), yerr=mens_gymnastics.Height.std())
ax.set_ylabel("Height (cm)")

plt.show()
